# %% [markdown]
# # **Gradient Boosting**

# %% [markdown]
# O algoritmo `Gradient Boosting` é uma técnica de aprendizado de máquina para problemas de regressão e classificação, que produz um modelo de previsão na forma de um conjunto de modelos de previsões fracos, geralmente árvores de decisão.
#
# O objetivo do algoritmo é criar uma corrente de modelos fracos, onde cada um tem como objetivo minimizar o erro do modelo anterior, por meio de uma função de perda.
#
# ![image.png](attachment:image.png)

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np

# %%
X, y = load_breast_cancer(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, stratify=y)

# %%
model = GradientBoostingClassifier(learning_rate=0.005, n_estimators=70, max_depth=3, verbose=1, random_state=42)

model.fit(X_train, y_train)
# Out:
#       Iter       Train Loss   Remaining Time
#          1           1.3115            1.01s
#          2           1.3024            0.84s
#          3           1.2933            0.84s
#          4           1.2844            0.85s
#          5           1.2755            0.85s
#          6           1.2668            0.84s
#          7           1.2581            0.81s
#          8           1.2496            0.77s
#          9           1.2411            0.75s
#         10           1.2328            0.71s
#         20           1.1532            0.45s
#         30           1.0805            0.30s
#         40           1.0145            0.21s
#         50           0.9549            0.13s
#         60           0.9003            0.06s
#         70           0.8499            0.00s
# GradientBoostingClassifier(learning_rate=0.005, n_estimators=70,
#                            random_state=42, verbose=1)

# %%
plt.plot(model.train_score_, color = "blue")
plt.xlabel('estimators')
plt.ylabel('error')

plt.grid(alpha = 0.3)
plt.show()

# %%
y_pred = model.predict(X_train)

acc_train = accuracy_score(y_train, y_pred)

# %%
y_pred = model.predict(X_test)

acc_test = accuracy_score(y_test, y_pred)

print(f'Accuracy test = {acc_test:.3%} | Accuracy train = {acc_train:.3%}')
# Out:
# Accuracy test = 94.149% | Accuracy train = 97.638%

# %% [markdown]
# ## **Referências**:
# - https://medium.com/equals-lab/uma-breve-introdu%C3%A7%C3%A3o-ao-algoritmo-de-machine-learning-gradient-boosting-utilizando-a-biblioteca-311285783099
